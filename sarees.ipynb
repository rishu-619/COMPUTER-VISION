# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import os
import urllib
import urllib.request

browser=webdriver.Chrome("C:\Program Files (x86)\chromedriver.exe")
browser.get('https://www.amazon.in/s?k=sarees+for+women&crid=Z17H444BQ9RT&sprefix=sarees+for+women%2Caps%2C305&ref=nb_sb_ss_i_3_16')

# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=1000):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(2000,3000)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/71YYx4WnZ3L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/41oZdY9X3wL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81dB8k+Cb-L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/41PQ9uJiWPL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71gS9nADNeL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81-uuEDvnQL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Pks4Q52wL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Gw2s5+5KL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Nfpvp1yhL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91YFGHzjm4L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61lIqW3EzmL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81wCS9fycmL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/810Kq7xQvtL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81qi7QCNSjL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91gd8AM2VOL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/916ROGKpL1L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81O-J6qiXvL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71y-fzR6gAL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61xFe9G7QtL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81ujgS5lKqL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/41nwPd1gH8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/710FxUypN1L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61DEObpFz0L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51djioBDKiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71lZhwh1ogL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71-fmGvNgSL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Pc9HRArSL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81QOe4fOisL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81JxWA-m4SL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91+auNsyHVL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71b5JqOaJcL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91S2jHgRHuL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71-BCt0A7CL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/9114kTDpPUL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71iSbIrFzcL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61k2713T2gL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/919lNOaU-GL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61xsiahrn3L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91Z3wEOJs0L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Q9ig3qklL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71AB3ZkmnfL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81O0YPQOrrL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71fS1s6PYeL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71zwNAtzGnL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/715Eq9LpiKL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61EP7HhumwL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61qy8shrPML._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81yBxlf-7KL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81LgiMrGpyL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81pBrnObeRL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71Hb3Xmhh5L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91K7kfay53L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61GunThFTVL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71TPLQLP0qL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71HFedKV9cL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81e+aJD2a-L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/41JdRg8vOdL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61He9peJOuL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71YBV8GOCYL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71rw+DPXfjL._AC_UL320_.jpg
# loop break
